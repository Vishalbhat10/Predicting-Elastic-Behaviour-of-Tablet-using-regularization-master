# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import seaborn as sns

# %%
Data = pd.read_csv('/Users/Navaneethan/Documents/Freelancing/Linear Regression/Suppoerting material.csv',index_col='Run' )

# %%
Data
# Out:
#        TCP (%)  SSG (%)  Screen size (mm)  Screen shape  square  \
# Run
# 1 L       12.5    12.25              0.85                     1
# 2 L       12.5    12.25              0.85                     1
# 3 L       12.5    12.25              0.85                     1
# 4 L       17.5     8.75              0.85                     1
# 5 L       17.5     8.75              0.85                     1
# 6 L       17.5     8.75              0.85                     1
# 7 L       17.5     8.75              0.85                     1
# 8 L       15.0    14.00              0.85                     1
# 9 L       15.0    14.00              0.85                     1
# 10 L      15.0    14.00              0.85                     1
# 11 L      15.0    14.00              0.85                     1
# 12 L      15.0    10.50              0.85                     1
# 13 L      15.0    10.50              0.85                     1
# 14 L      15.0    10.50              0.85                     1
# 15 L      15.0    10.50              0.85                     1
# 16 L      20.0    14.00              0.85                     1
# 17 L      20.0    14.00              0.85                     1
# 18 L      20.0    14.00              0.85                     1
# 19 L      20.0    14.00              0.85                     1
# 20 L      20.0     7.00              0.85                     1
# 21 L      20.0     7.00              0.85                     1
# 22 L      20.0     7.00              0.85                     1
# 23 L      20.0     7.00              0.85                     1
# 24 L      15.0    10.50              0.85                     1
# 25 L      15.0    10.50              0.85                     1
# 26 L      15.0    10.50              0.85                     1
# 27 L      15.0    10.50              0.85                     1
# 28 L      12.5     8.75              0.85                     1
# 29 L      12.5     8.75              0.85                     1
# 30 L      12.5     8.75              0.85                     1
# ...        ...      ...               ...                   ...
# 7 C       23.0    14.00              0.69                     0
# 8 C       23.0    14.00              0.69                     0
# 9 C       23.0    14.00              0.69                     0
# 10 C      23.0    14.00              0.69                     0
# 11 C      23.0    14.00              0.69                     0
# 12 C      23.0    14.00              0.69                     0
# 13 C      23.0    14.00              0.69                     0
# 14 C      23.0    14.00              0.69                     0
# 15 C      23.0    14.00              0.69                     0
# 16 C      23.0    14.00              0.69                     0
# 17 C      23.0    14.00              1.04                     0
# 18 C      23.0    14.00              1.04                     0
# 19 C      23.0    14.00              1.04                     0
# 20 C      23.0    14.00              1.04                     0
# 21 C      23.0    14.00              0.84                     0
# 22 C      23.0    14.00              0.84                     0
# 23 C      23.0    14.00              0.84                     0
# 24 C      23.0    14.00              0.84                     0
# 25 C      23.0    14.00              0.69                     0
# 26 C      23.0    14.00              0.69                     0
# 27 C      23.0    14.00              0.69                     0
# 28 C      23.0    14.00              0.69                     0
# 29 C      23.0    14.00              0.69                     0
# 30 C      23.0    14.00              0.69                     0
# 31 C      23.0    14.00              0.69                     0
# 32 C      23.0    14.00              0.69                     0
# 33 C      23.0    14.00              0.69                     0
# 34 C      23.0    14.00              0.69                     0
# 35 C      23.0    14.00              0.69                     0
# 36 C      23.0    14.00              0.69                     0
#
#        Screen shape  round  Water (%)  Particle size (%)> 500 µm  \
# Run
# 1 L                      0       26.5                       30.9
# 2 L                      0       26.5                       30.9
# 3 L                      0       26.5                       30.9
# 4 L                      0       26.5                       23.8
# 5 L                      0       26.5                       23.8
# 6 L                      0       26.5                       23.8
# 7 L                      0       26.5                       23.8
# 8 L                      0       17.4                       26.3
# 9 L                      0       17.4                       26.3
# 10 L                     0       17.4                       26.3
# 11 L                     0       17.4                       26.3
# 12 L                     0       20.5                       21.9
# 13 L                     0       20.5                       21.9
# 14 L                     0       20.5                       21.9
# 15 L                     0       20.5                       21.9
# 16 L                     0       14.6                       26.3
# 17 L                     0       14.6                       26.3
# 18 L                     0       14.6                       26.3
# 19 L                     0       14.6                       26.3
# 20 L                     0       26.5                       23.4
# 21 L                     0       26.5                       23.4
# 22 L                     0       26.5                       23.4
# 23 L                     0       26.5                       23.4
# 24 L                     0       19.8                       23.8
# 25 L                     0       19.8                       23.8
# 26 L                     0       19.8                       23.8
# 27 L                     0       19.8                       23.8
# 28 L                     0       26.5                       22.2
# 29 L                     0       26.5                       22.2
# 30 L                     0       26.5                       22.2
# ...                    ...        ...                        ...
# 7 C                      1       16.5                       14.2
# 8 C                      1       16.5                       14.2
# 9 C                      1       16.5                        9.1
# 10 C                     1       16.5                        9.1
# 11 C                     1       16.5                        9.1
# 12 C                     1       16.5                        9.1
# 13 C                     1       16.5                        2.6
# 14 C                     1       16.5                        2.6
# 15 C                     1       16.5                        2.6
# 16 C                     1       16.5                        2.6
# 17 C                     1       16.5                       20.0
# 18 C                     1       16.5                       20.0
# 19 C                     1       16.5                       20.0
# 20 C                     1       16.5                       20.0
# 21 C                     1       16.5                       19.0
# 22 C                     1       16.5                       19.0
# 23 C                     1       16.5                       19.0
# 24 C                     1       16.5                       19.0
# 25 C                     1       15.8                        8.9
# 26 C                     1       15.8                        8.9
# 27 C                     1       15.8                        8.9
# 28 C                     1       15.8                        8.9
# 29 C                     1       15.8                        5.9
# 30 C                     1       15.8                        5.9
# 31 C                     1       15.8                        5.9
# 32 C                     1       15.8                        5.9
# 33 C                     1       15.8                       11.1
# 34 C                     1       15.8                       11.1
# 35 C                     1       15.8                       11.1
# 36 C                     1       15.8                       11.1
#
#        Particle size (%)250 - 500 µm  Particle size (%)150 - 250 µm  \
# Run
# 1 L                             22.8                           15.6
# 2 L                             22.8                           15.6
# 3 L                             22.8                           15.6
# 4 L                             19.0                           20.3
# 5 L                             19.0                           20.3
# 6 L                             19.0                           20.3
# 7 L                             19.0                           20.3
# 8 L                             22.4                           15.4
# 9 L                             22.4                           15.4
# 10 L                            22.4                           15.4
# 11 L                            22.4                           15.4
# 12 L                            21.2                           12.7
# 13 L                            21.2                           12.7
# 14 L                            21.2                           12.7
# 15 L                            21.2                           12.7
# 16 L                            20.4                           10.8
# 17 L                            20.4                           10.8
# 18 L                            20.4                           10.8
# 19 L                            20.4                           10.8
# 20 L                            20.6                           13.8
# 21 L                            20.6                           13.8
# 22 L                            20.6                           13.8
# 23 L                            20.6                           13.8
# 24 L                            19.4                           12.7
# 25 L                            19.4                           12.7
# 26 L                            19.4                           12.7
# 27 L                            19.4                           12.7
# 28 L                            23.6                           14.2
# 29 L                            23.6                           14.2
# 30 L                            23.6                           14.2
# ...                              ...                            ...
# 7 C                             23.7                           14.7
# 8 C                             23.7                           14.7
# 9 C                             29.4                           14.9
# 10 C                            29.4                           14.9
# 11 C                            29.4                           14.9
# 12 C                            29.4                           14.9
# 13 C                            22.1                           20.1
# 14 C                            22.1                           20.1
# 15 C                            22.1                           20.1
# 16 C                            22.1                           20.1
# 17 C                            28.7                           15.4
# 18 C                            28.7                           15.4
# 19 C                            28.7                           15.4
# 20 C                            28.7                           15.4
# 21 C                            28.5                           13.0
# 22 C                            28.5                           13.0
# 23 C                            28.5                           13.0
# 24 C                            28.5                           13.0
# 25 C                            34.7                           21.9
# 26 C                            34.7                           21.9
# 27 C                            34.7                           21.9
# 28 C                            34.7                           21.9
# 29 C                            33.4                           20.5
# 30 C                            33.4                           20.5
# 31 C                            33.4                           20.5
# 32 C                            33.4                           20.5
# 33 C                            41.7                           15.8
# 34 C                            41.7                           15.8
# 35 C                            41.7                           15.8
# 36 C                            41.7                           15.8
#
#        Particle size (%)0 - 150 µm  Compression Pressure (MPa)  Ha(mm)  \
# Run
# 1 L                           35.8                      104.09    2.55
# 2 L                           35.8                      138.78    2.47
# 3 L                           35.8                      173.48    2.47
# 4 L                           35.9                       69.39    2.86
# 5 L                           35.9                      104.09    2.64
# 6 L                           35.9                      138.78    2.43
# 7 L                           35.9                      173.48    2.31
# 8 L                           36.6                       69.39    3.04
# 9 L                           36.6                      104.09    2.61
# 10 L                          36.6                      138.78    2.47
# 11 L                          36.6                      173.48    2.53
# 12 L                          43.6                       69.39    2.98
# 13 L                          43.6                      104.09    2.65
# 14 L                          43.6                      138.78    2.53
# 15 L                          43.6                      173.48    2.48
# 16 L                          42.6                       69.39    2.79
# 17 L                          42.6                      104.09    2.59
# 18 L                          42.6                      138.78    2.45
# 19 L                          42.6                      173.48    2.31
# 20 L                          41.7                       69.39    2.79
# 21 L                          41.7                      104.09    2.57
# 22 L                          41.7                      138.78    2.42
# 23 L                          41.7                      173.48    2.34
# 24 L                          44.8                       69.39    2.83
# 25 L                          44.8                      104.09    2.58
# 26 L                          44.8                      138.78    2.46
# 27 L                          44.8                      173.48    2.36
# 28 L                          39.7                       69.39    2.84
# 29 L                          39.7                      104.09    2.63
# 30 L                          39.7                      138.78    2.49
# ...                            ...                         ...     ...
# 7 C                           47.1                      138.78    2.23
# 8 C                           47.1                      173.48    2.09
# 9 C                           46.3                       69.39    2.59
# 10 C                          46.3                      104.09    2.39
# 11 C                          46.3                      138.78    2.18
# 12 C                          46.3                      173.48    2.12
# 13 C                          54.8                       69.39    2.63
# 14 C                          54.8                      104.09    2.39
# 15 C                          54.8                      138.78    2.24
# 16 C                          54.8                      173.48    2.11
# 17 C                          35.7                       69.39    2.45
# 18 C                          35.7                      104.09    2.25
# 19 C                          35.7                      138.78    2.14
# 20 C                          35.7                      173.48    2.02
# 21 C                          38.9                       69.39    2.44
# 22 C                          38.9                      104.09    2.22
# 23 C                          38.9                      138.78    2.11
# 24 C                          38.9                      173.48    2.01
# 25 C                          34.6                       69.39    2.47
# 26 C                          34.6                      104.09    2.26
# 27 C                          34.6                      138.78    2.13
# 28 C                          34.6                      173.48    1.98
# 29 C                          40.2                       69.39    2.46
# 30 C                          40.2                      104.09    2.27
# 31 C                          40.2                      138.78    2.17
# 32 C                          40.2                      173.48    2.07
# 33 C                          31.4                       69.39    2.61
# 34 C                          31.4                      104.09    2.36
# 35 C                          31.4                      138.78    2.22
# 36 C                          31.4                      173.48    2.13
#
#        Hb(mm)  Hc(mm)  Db (mm)  Dc (mm)  IAR (%)  CAR (%)  VSR (%)  \
# Run
# 1 L      2.87    2.93        6     6.01    12.29    14.94    15.45
# 2 L      2.82    2.88        6     6.02    14.27    16.94    17.72
# 3 L      2.87    2.88        6     6.00    16.11    16.79    16.66
# 4 L      3.14    3.18        6     6.01     9.68    11.02    11.39
# 5 L      2.95    2.97        6     6.02    11.68    12.26    12.89
# 6 L      2.78    2.78        6     6.02    14.12    14.40    15.16
# 7 L      2.70    2.72        6     6.01    16.98    17.47    18.00
# 8 L      3.32    3.32        6     6.03     9.44     9.13    10.10
# 9 L      2.92    2.95        6     6.02    11.91    13.06    13.94
# 10 L     2.81    2.80        6     6.01    13.88    13.58    13.96
# 11 L     2.87    2.97        6     6.02    13.59    17.36    18.01
# 12 L     3.25    3.25        6     6.02     8.96     9.10     9.95
# 13 L     2.95    2.97        6     6.01    11.28    11.96    12.20
# 14 L     2.88    2.87        6     6.00    13.62    13.14    13.14
# 15 L     2.82    2.83        6     6.00    13.44    14.04    14.04
# 16 L     3.05    3.07        6     6.00     9.62    10.09     9.97
# 17 L     2.89    2.95        6     6.00    11.74    13.88    14.01
# 18 L     2.79    2.78        6     6.01    13.85    13.69    14.07
# 19 L     2.68    2.70        6     6.02    15.96    17.01    17.92
# 20 L     3.07    3.03        6     6.00     9.75     8.54     8.42
# 21 L     2.88    2.90        6     6.00    11.97    12.89    13.01
# 22 L     2.76    2.82        6     6.01    13.91    16.34    16.73
# 23 L     2.72    2.72        6     6.02    16.06    15.95    16.86
# 24 L     3.10    3.13        6     6.00     9.55    10.68    10.56
# 25 L     2.88    2.88        6     6.00    11.65    11.93    12.05
# 26 L     2.80    2.80        6     6.01    13.77    13.86    14.24
# 27 L     2.73    2.75        6     6.02    15.79    16.52    17.43
# 28 L     3.11    3.13        6     5.97     9.56    10.26     9.28
# 29 L     2.93    2.95        6     5.99    11.60    12.18    11.81
# 30 L     2.83    2.85        6     5.99    13.70    14.45    14.07
# ...       ...     ...      ...      ...      ...      ...      ...
# 7 C      2.65    2.52        6     5.99    19.03    12.90    12.64
# 8 C      2.46    2.43        6     5.99    17.51    16.23    15.84
# 9 C      3.00    2.88        6     6.00    15.80    11.30    11.18
# 10 C     2.79    2.68        6     5.99    16.82    12.48    12.11
# 11 C     2.51    2.48        6     5.98    15.20    13.83    12.94
# 12 C     2.49    2.45        6     5.99    17.39    15.33    15.08
# 13 C     2.90    2.88        6     5.99     9.94     9.45     8.96
# 14 C     2.68    2.63        6     5.98    12.29    10.32     9.58
# 15 C     2.56    2.55        6     5.98    14.50    13.87    13.12
# 16 C     2.46    2.43        6     5.98    16.93    15.49    14.72
# 17 C     2.84    2.75        6     5.97    15.97    12.14    10.90
# 18 C     2.73    2.57        6     5.98    21.37    14.20    13.44
# 19 C     2.53    2.48        6     5.98    18.13    16.09    15.44
# 20 C     2.47    2.40        6     5.99    22.18    18.95    18.55
# 21 C     2.94    2.72        6     6.01    20.40    11.27    11.64
# 22 C     2.71    2.52        6     6.01    22.44    13.53    14.03
# 23 C     2.52    2.45        6     6.02    19.39    15.95    16.73
# 24 C     2.43    2.40        6     6.01    20.67    19.28    19.82
# 25 C     2.90    2.77        6     5.99    17.59    12.13    11.88
# 26 C     2.65    2.57        6     5.99    17.17    13.58    13.20
# 27 C     2.58    2.47        6     5.98    21.49    16.01    15.24
# 28 C     2.42    2.38        6     6.01    22.07    20.47    20.74
# 29 C     2.87    2.77        6     5.99    17.01    12.61    12.36
# 30 C     2.60    2.57        6     5.99    14.63    12.99    12.61
# 31 C     2.55    2.53        6     5.98    17.33    16.74    15.96
# 32 C     2.47    2.47        6     6.01    19.18    18.98    19.25
# 33 C     2.88    2.87        6     5.99    10.65    10.02     9.65
# 34 C     2.68    2.67        6     6.00    13.48    12.80    12.93
# 35 C     2.56    2.52        6     6.33    15.09    13.16    25.81
# 36 C     2.49    2.48        6     5.98    17.02    16.60    15.95
#
#        Elastic work (Nm)
# Run
# 1 L                -0.20
# 2 L                -0.34
# 3 L                -0.50
# 4 L                -0.11
# 5 L                -0.21
# 6 L                -0.34
# 7 L                -0.50
# 8 L                -0.11
# 9 L                -0.21
# 10 L               -0.34
# 11 L               -0.34
# 12 L               -0.11
# 13 L               -0.21
# 14 L               -0.33
# 15 L               -0.34
# 16 L               -0.11
# 17 L               -0.21
# 18 L               -0.34
# 19 L               -0.50
# 20 L               -0.11
# 21 L               -0.21
# 22 L               -0.34
# 23 L               -0.50
# 24 L               -0.11
# 25 L               -0.21
# 26 L               -0.34
# 27 L               -0.50
# 28 L               -0.11
# 29 L               -0.21
# 30 L               -0.34
# ...                  ...
# 7 C                -0.29
# 8 C                -0.43
# 9 C                -0.10
# 10 C               -0.18
# 11 C               -0.29
# 12 C               -0.43
# 13 C               -0.09
# 14 C               -0.18
# 15 C               -0.29
# 16 C               -0.42
# 17 C               -0.10
# 18 C               -0.20
# 19 C               -0.32
# 20 C               -0.49
# 21 C               -0.10
# 22 C               -0.21
# 23 C               -0.32
# 24 C               -0.49
# 25 C               -0.10
# 26 C               -0.19
# 27 C               -0.32
# 28 C               -0.48
# 29 C               -0.10
# 30 C               -0.19
# 31 C               -0.32
# 32 C               -0.49
# 33 C               -0.10
# 34 C               -0.19
# 35 C               -0.30
# 36 C               -0.44
#
# [166 rows x 20 columns]

# %%
plot.rcParams["figure.figsize"] = [20,15]
sns.heatmap(Data.corr(), annot= True)

# %%
Data_L = Data.loc['1 L':'82 L']
Data_L
# Out:
#        TCP (%)  SSG (%)  Screen size (mm)  Screen shape  square  \
# Run
# 1 L       12.5    12.25              0.85                   1.0
# 2 L       12.5    12.25              0.85                   1.0
# 3 L       12.5    12.25              0.85                   1.0
# 4 L       17.5     8.75              0.85                   1.0
# 5 L       17.5     8.75              0.85                   1.0
# 6 L       17.5     8.75              0.85                   1.0
# 7 L       17.5     8.75              0.85                   1.0
# 8 L       15.0    14.00              0.85                   1.0
# 9 L       15.0    14.00              0.85                   1.0
# 10 L      15.0    14.00              0.85                   1.0
# 11 L      15.0    14.00              0.85                   1.0
# 12 L      15.0    10.50              0.85                   1.0
# 13 L      15.0    10.50              0.85                   1.0
# 14 L      15.0    10.50              0.85                   1.0
# 15 L      15.0    10.50              0.85                   1.0
# 16 L      20.0    14.00              0.85                   1.0
# 17 L      20.0    14.00              0.85                   1.0
# 18 L      20.0    14.00              0.85                   1.0
# 19 L      20.0    14.00              0.85                   1.0
# 20 L      20.0     7.00              0.85                   1.0
# 21 L      20.0     7.00              0.85                   1.0
# 22 L      20.0     7.00              0.85                   1.0
# 23 L      20.0     7.00              0.85                   1.0
# 24 L      15.0    10.50              0.85                   1.0
# 25 L      15.0    10.50              0.85                   1.0
# 26 L      15.0    10.50              0.85                   1.0
# 27 L      15.0    10.50              0.85                   1.0
# 28 L      12.5     8.75              0.85                   1.0
# 29 L      12.5     8.75              0.85                   1.0
# 30 L      12.5     8.75              0.85                   1.0
# ...        ...      ...               ...                   ...
# 53 L      10.0    14.00              0.85                   1.0
# 54 L      10.0    14.00              0.85                   1.0
# 55 L      20.0    14.00              1.04                   0.0
# 56 L      20.0    14.00              1.04                   0.0
# 57 L      20.0    14.00              1.04                   0.0
# 58 L      20.0    14.00              1.04                   0.0
# 59 L      20.0    14.00              0.85                   1.0
# 60 L      20.0    14.00              0.85                   1.0
# 61 L      20.0    14.00              0.85                   1.0
# 62 L      20.0    14.00              0.85                   1.0
# 63 L      20.0    14.00              0.85                   1.0
# 64 L      20.0    14.00              0.85                   1.0
# 65 L      20.0    14.00              0.85                   1.0
# 66 L      20.0    14.00              0.85                   1.0
# 67 L      20.0    14.00              0.85                   1.0
# 68 L      20.0    14.00              0.85                   1.0
# 69 L      20.0    14.00              0.85                   1.0
# 70 L      20.0    14.00              0.85                   1.0
# 71 L      20.0    14.00              1.04                   0.0
# 72 L      20.0    14.00              1.04                   0.0
# 73 L      20.0    14.00              1.04                   0.0
# 74 L      20.0    14.00              1.04                   0.0
# 75 L      20.0    14.00              0.69                   0.0
# 76 L      20.0    14.00              0.69                   0.0
# 77 L      20.0    14.00              0.69                   0.0
# 78 L      20.0    14.00              0.69                   0.0
# 79 L      20.0    14.00              0.69                   0.0
# 80 L      20.0    14.00              0.69                   0.0
# 81 L      20.0    14.00              0.69                   0.0
# 82 L      20.0    14.00              0.69                   0.0
#
#        Screen shape  round  Water (%)  Particle size (%)> 500 µm  \
# Run
# 1 L                    0.0       26.5                       30.9
# 2 L                    0.0       26.5                       30.9
# 3 L                    0.0       26.5                       30.9
# 4 L                    0.0       26.5                       23.8
# 5 L                    0.0       26.5                       23.8
# 6 L                    0.0       26.5                       23.8
# 7 L                    0.0       26.5                       23.8
# 8 L                    0.0       17.4                       26.3
# 9 L                    0.0       17.4                       26.3
# 10 L                   0.0       17.4                       26.3
# 11 L                   0.0       17.4                       26.3
# 12 L                   0.0       20.5                       21.9
# 13 L                   0.0       20.5                       21.9
# 14 L                   0.0       20.5                       21.9
# 15 L                   0.0       20.5                       21.9
# 16 L                   0.0       14.6                       26.3
# 17 L                   0.0       14.6                       26.3
# 18 L                   0.0       14.6                       26.3
# 19 L                   0.0       14.6                       26.3
# 20 L                   0.0       26.5                       23.4
# 21 L                   0.0       26.5                       23.4
# 22 L                   0.0       26.5                       23.4
# 23 L                   0.0       26.5                       23.4
# 24 L                   0.0       19.8                       23.8
# 25 L                   0.0       19.8                       23.8
# 26 L                   0.0       19.8                       23.8
# 27 L                   0.0       19.8                       23.8
# 28 L                   0.0       26.5                       22.2
# 29 L                   0.0       26.5                       22.2
# 30 L                   0.0       26.5                       22.2
# ...                    ...        ...                        ...
# 53 L                   0.0       26.5                       28.4
# 54 L                   0.0       26.5                       28.4
# 55 L                   1.0       17.2                       29.1
# 56 L                   1.0       17.2                       29.1
# 57 L                   1.0       17.2                       29.1
# 58 L                   1.0       17.2                       29.1
# 59 L                   0.0       17.8                       33.9
# 60 L                   0.0       17.8                       33.9
# 61 L                   0.0       17.8                       33.9
# 62 L                   0.0       17.8                       33.9
# 63 L                   0.0       26.4                       21.1
# 64 L                   0.0       26.4                       21.1
# 65 L                   0.0       26.4                       21.1
# 66 L                   0.0       26.4                       21.1
# 67 L                   0.0       25.2                       22.4
# 68 L                   0.0       25.2                       22.4
# 69 L                   0.0       25.2                       22.4
# 70 L                   0.0       25.2                       22.4
# 71 L                   1.0       24.4                       24.5
# 72 L                   1.0       24.4                       24.5
# 73 L                   1.0       24.4                       24.5
# 74 L                   1.0       24.4                       24.5
# 75 L                   1.0       24.1                        5.3
# 76 L                   1.0       24.1                        5.3
# 77 L                   1.0       24.1                        5.3
# 78 L                   1.0       24.1                        5.3
# 79 L                   1.0       18.3                        9.3
# 80 L                   1.0       18.3                        9.3
# 81 L                   1.0       18.3                        9.3
# 82 L                   1.0       18.3                        9.3
#
#        Particle size (%)250 - 500 µm  Particle size (%)150 - 250 µm  \
# Run
# 1 L                             22.8                           15.6
# 2 L                             22.8                           15.6
# 3 L                             22.8                           15.6
# 4 L                             19.0                           20.3
# 5 L                             19.0                           20.3
# 6 L                             19.0                           20.3
# 7 L                             19.0                           20.3
# 8 L                             22.4                           15.4
# 9 L                             22.4                           15.4
# 10 L                            22.4                           15.4
# 11 L                            22.4                           15.4
# 12 L                            21.2                           12.7
# 13 L                            21.2                           12.7
# 14 L                            21.2                           12.7
# 15 L                            21.2                           12.7
# 16 L                            20.4                           10.8
# 17 L                            20.4                           10.8
# 18 L                            20.4                           10.8
# 19 L                            20.4                           10.8
# 20 L                            20.6                           13.8
# 21 L                            20.6                           13.8
# 22 L                            20.6                           13.8
# 23 L                            20.6                           13.8
# 24 L                            19.4                           12.7
# 25 L                            19.4                           12.7
# 26 L                            19.4                           12.7
# 27 L                            19.4                           12.7
# 28 L                            23.6                           14.2
# 29 L                            23.6                           14.2
# 30 L                            23.6                           14.2
# ...                              ...                            ...
# 53 L                            17.1                           11.9
# 54 L                            17.1                           11.9
# 55 L                            25.5                            8.2
# 56 L                            25.5                            8.2
# 57 L                            25.5                            8.2
# 58 L                            25.5                            8.2
# 59 L                            22.5                            6.7
# 60 L                            22.5                            6.7
# 61 L                            22.5                            6.7
# 62 L                            22.5                            6.7
# 63 L                            22.9                           11.8
# 64 L                            22.9                           11.8
# 65 L                            22.9                           11.8
# 66 L                            22.9                           11.8
# 67 L                            23.7                           11.0
# 68 L                            23.7                           11.0
# 69 L                            23.7                           11.0
# 70 L                            23.7                           11.0
# 71 L                            19.6                           10.9
# 72 L                            19.6                           10.9
# 73 L                            19.6                           10.9
# 74 L                            19.6                           10.9
# 75 L                            28.2                           20.5
# 76 L                            28.2                           20.5
# 77 L                            28.2                           20.5
# 78 L                            28.2                           20.5
# 79 L                            34.1                           12.0
# 80 L                            34.1                           12.0
# 81 L                            34.1                           12.0
# 82 L                            34.1                           12.0
#
#        Particle size (%)0 - 150 µm  Compression Pressure (MPa)  Ha (mm)  \
# Run
# 1 L                           35.8                      104.09     2.55
# 2 L                           35.8                      138.78     2.47
# 3 L                           35.8                      173.48     2.47
# 4 L                           35.9                       69.39     2.86
# 5 L                           35.9                      104.09     2.64
# 6 L                           35.9                      138.78     2.43
# 7 L                           35.9                      173.48     2.31
# 8 L                           36.6                       69.39     3.04
# 9 L                           36.6                      104.09     2.61
# 10 L                          36.6                      138.78     2.47
# 11 L                          36.6                      173.48     2.53
# 12 L                          43.6                       69.39     2.98
# 13 L                          43.6                      104.09     2.65
# 14 L                          43.6                      138.78     2.53
# 15 L                          43.6                      173.48     2.48
# 16 L                          42.6                       69.39     2.79
# 17 L                          42.6                      104.09     2.59
# 18 L                          42.6                      138.78     2.45
# 19 L                          42.6                      173.48     2.31
# 20 L                          41.7                       69.39     2.79
# 21 L                          41.7                      104.09     2.57
# 22 L                          41.7                      138.78     2.42
# 23 L                          41.7                      173.48     2.34
# 24 L                          44.8                       69.39     2.83
# 25 L                          44.8                      104.09     2.58
# 26 L                          44.8                      138.78     2.46
# 27 L                          44.8                      173.48     2.36
# 28 L                          39.7                       69.39     2.84
# 29 L                          39.7                      104.09     2.63
# 30 L                          39.7                      138.78     2.49
# ...                            ...                         ...      ...
# 53 L                          41.9                      138.78     2.39
# 54 L                          41.9                      173.48     2.34
# 55 L                          36.7                       69.39     2.56
# 56 L                          36.7                      104.09     2.37
# 57 L                          36.7                      138.78     2.21
# 58 L                          36.7                      173.48     2.09
# 59 L                          36.4                       69.39     2.59
# 60 L                          36.4                      104.09     2.36
# 61 L                          36.4                      138.78     2.23
# 62 L                          36.4                      173.48     2.15
# 63 L                          44.1                       69.39     2.63
# 64 L                          44.1                      104.09     2.37
# 65 L                          44.1                      138.78     2.25
# 66 L                          44.1                      173.48     2.23
# 67 L                          42.5                       69.39     2.66
# 68 L                          42.5                      104.09     2.34
# 69 L                          42.5                      138.78     2.24
# 70 L                          42.5                      173.48     2.12
# 71 L                          44.5                       69.39     2.59
# 72 L                          44.5                      104.09     2.38
# 73 L                          44.5                      138.78     2.24
# 74 L                          44.5                      173.48     2.10
# 75 L                          45.2                       69.39     2.57
# 76 L                          45.2                      104.09     2.36
# 77 L                          45.2                      138.78     2.25
# 78 L                          45.2                      173.48     2.14
# 79 L                          44.5                       69.39     2.54
# 80 L                          44.5                      104.09     2.36
# 81 L                          44.5                      138.78     2.25
# 82 L                          44.5                      173.48     2.06
#
#        Hb (mm)  Hc (mm)  Db (mm)  Dc (mm)  IAR (%)  CAR (%)  VSR (%)  \
# Run
# 1 L       2.87     2.93      6.0     6.01    12.29    14.94    15.45
# 2 L       2.82     2.88      6.0     6.02    14.27    16.94    17.72
# 3 L       2.87     2.88      6.0     6.00    16.11    16.79    16.66
# 4 L       3.14     3.18      6.0     6.01     9.68    11.02    11.39
# 5 L       2.95     2.97      6.0     6.02    11.68    12.26    12.89
# 6 L       2.78     2.78      6.0     6.02    14.12    14.40    15.16
# 7 L       2.70     2.72      6.0     6.01    16.98    17.47    18.00
# 8 L       3.32     3.32      6.0     6.03     9.44     9.13    10.10
# 9 L       2.92     2.95      6.0     6.02    11.91    13.06    13.94
# 10 L      2.81     2.80      6.0     6.01    13.88    13.58    13.96
# 11 L      2.87     2.97      6.0     6.02    13.59    17.36    18.01
# 12 L      3.25     3.25      6.0     6.02     8.96     9.10     9.95
# 13 L      2.95     2.97      6.0     6.01    11.28    11.96    12.20
# 14 L      2.88     2.87      6.0     6.00    13.62    13.14    13.14
# 15 L      2.82     2.83      6.0     6.00    13.44    14.04    14.04
# 16 L      3.05     3.07      6.0     6.00     9.62    10.09     9.97
# 17 L      2.89     2.95      6.0     6.00    11.74    13.88    14.01
# 18 L      2.79     2.78      6.0     6.01    13.85    13.69    14.07
# 19 L      2.68     2.70      6.0     6.02    15.96    17.01    17.92
# 20 L      3.07     3.03      6.0     6.00     9.75     8.54     8.42
# 21 L      2.88     2.90      6.0     6.00    11.97    12.89    13.01
# 22 L      2.76     2.82      6.0     6.01    13.91    16.34    16.73
# 23 L      2.72     2.72      6.0     6.02    16.06    15.95    16.86
# 24 L      3.10     3.13      6.0     6.00     9.55    10.68    10.56
# 25 L      2.88     2.88      6.0     6.00    11.65    11.93    12.05
# 26 L      2.80     2.80      6.0     6.01    13.77    13.86    14.24
# 27 L      2.73     2.75      6.0     6.02    15.79    16.52    17.43
# 28 L      3.11     3.13      6.0     5.97     9.56    10.26     9.28
# 29 L      2.93     2.95      6.0     5.99    11.60    12.18    11.81
# 30 L      2.83     2.85      6.0     5.99    13.70    14.45    14.07
# ...        ...      ...      ...      ...      ...      ...      ...
# 53 L      2.74     2.75      6.0     5.98    14.62    14.94    14.30
# 54 L      2.73     2.73      6.0     5.98    16.44    16.67    16.03
# 55 L      2.83     2.83      6.0     6.01    10.51    10.81    11.06
# 56 L      2.68     2.70      6.0     6.01    12.96    13.91    14.29
# 57 L      2.55     2.53      6.0     5.99    15.24    14.55    14.29
# 58 L      2.46     2.43      6.0     5.99    17.90    16.59    16.33
# 59 L      2.85     2.83      6.0     5.98    10.11     9.42     8.69
# 60 L      2.66     2.65      6.0     5.98    12.36    12.11    11.49
# 61 L      2.56     2.57      6.0     5.97    14.59    14.84    13.70
# 62 L      2.51     2.48      6.0     5.97    17.04    15.62    14.46
# 63 L      2.89     2.88      6.0     6.01    10.09     9.84    10.09
# 64 L      2.67     2.65      6.0     6.00    12.40    11.66    11.66
# 65 L      2.57     2.57      6.0     6.01    14.63    14.30    14.56
# 66 L      2.60     2.60      6.0     6.00    16.43    16.55    16.68
# 67 L      2.93     2.90      6.0     6.00    10.10     9.00     9.12
# 68 L      2.63     2.60      6.0     6.01    12.49    11.35    11.60
# 69 L      2.57     2.55      6.0     6.00    14.56    13.81    13.81
# 70 L      2.48     2.48      6.0     6.00    17.07    17.07    17.07
# 71 L      2.85     2.83      6.0     6.02     9.96     9.32    10.17
# 72 L      2.67     2.65      6.0     6.02    12.26    11.53    12.28
# 73 L      2.57     2.57      6.0     6.00    14.64    14.47    14.47
# 74 L      2.48     2.47      6.0     6.00    18.08    17.36    17.36
# 75 L      2.83     2.82      6.0     6.02    10.02     9.41    10.14
# 76 L      2.65     2.63      6.0     6.00    12.46    11.76    11.88
# 77 L      2.57     2.55      6.0     6.04    14.70    13.59    14.98
# 78 L      2.51     2.50      6.0     6.02    17.12    16.82    17.60
# 79 L      2.82     2.80      6.0     5.98    10.82    10.19     9.46
# 80 L      2.73     2.63      6.0     5.98    15.64    11.58    10.84
# 81 L      2.59     2.58      6.0     5.98    15.16    14.70    13.94
# 82 L      2.45     2.43      6.0     5.97    18.89    18.11    16.93
#
#        Elastic work (Nm)
# Run
# 1 L                -0.20
# 2 L                -0.34
# 3 L                -0.50
# 4 L                -0.11
# 5 L                -0.21
# 6 L                -0.34
# 7 L                -0.50
# 8 L                -0.11
# 9 L                -0.21
# 10 L               -0.34
# 11 L               -0.34
# 12 L               -0.11
# 13 L               -0.21
# 14 L               -0.33
# 15 L               -0.34
# 16 L               -0.11
# 17 L               -0.21
# 18 L               -0.34
# 19 L               -0.50
# 20 L               -0.11
# 21 L               -0.21
# 22 L               -0.34
# 23 L               -0.50
# 24 L               -0.11
# 25 L               -0.21
# 26 L               -0.34
# 27 L               -0.50
# 28 L               -0.11
# 29 L               -0.21
# 30 L               -0.34
# ...                  ...
# 53 L               -0.34
# 54 L               -0.51
# 55 L               -0.10
# 56 L               -0.19
# 57 L               -0.32
# 58 L               -0.48
# 59 L               -0.10
# 60 L               -0.19
# 61 L               -0.32
# 62 L               -0.48
# 63 L               -0.10
# 64 L               -0.19
# 65 L               -0.32
# 66 L               -0.48
# 67 L               -0.11
# 68 L               -0.19
# 69 L               -0.32
# 70 L               -0.48
# 71 L               -0.10
# 72 L               -0.19
# 73 L               -0.32
# 74 L               -0.52
# 75 L               -0.10
# 76 L               -0.19
# 77 L               -0.32
# 78 L               -0.48
# 79 L               -0.10
# 80 L               -0.20
# 81 L               -0.32
# 82 L               -0.52
#
# [82 rows x 20 columns]

# %%
Data_L.columns
# Out:
# Index(['TCP (%)', 'SSG (%)', 'Screen size (mm)', 'Screen shape  square',
#        'Screen shape  round', 'Water (%)', 'Particle size (%)> 500 µm',
#        'Particle size (%)250 - 500 µm', 'Particle size (%)150 - 250 µm',
#        'Particle size (%)0 - 150 µm', 'Compression Pressure (MPa)', 'Ha (mm)',
#        'Hb (mm)', 'Hc (mm)', 'Db (mm)', 'Dc (mm)', 'IAR (%)', 'CAR (%)',
#        'VSR (%)', 'Elastic work (Nm)'],
#       dtype='object')

# %% [markdown]
# ### Correlation Matrix

# %%
plot.rcParams["figure.figsize"] = [18,12]
sns.heatmap(Data_L.corr(), annot= True)

# %% [markdown]
# # Laboratory scale sample runs

# %% [markdown]
# ### Linear Regression with K-Fold Cross Validation for Ha as Response Variable

# %%
import sklearn
from sklearn import metrics
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression

# %%
X = pd.DataFrame(Data_L['Compression Pressure (MPa)'])
y = pd.DataFrame(Data_L['Ha (mm)'])

model = LinearRegression()
scores = []
kfold = KFold(n_splits=2, shuffle=True, random_state=42)

for i, (train, test) in enumerate(kfold.split(X, y)):
    model.fit(X.iloc[train,:], y.iloc[train,:])
    score = model.score(X.iloc[test,:], y.iloc[test,:])
    scores.append(score)

print(scores)
# Out:
# [0.5979622948900492, 0.6585377155746324]

# %%
X = pd.DataFrame(Data_L[['Compression Pressure (MPa)','Particle size (%)150 - 250 µm']])
y = pd.DataFrame(Data_L['Ha (mm)'])

model = LinearRegression()
scores = []
kfold = KFold(n_splits=2, shuffle=True, random_state=42)

for i, (train, test) in enumerate(kfold.split(X, y)):
    model.fit(X.iloc[train,:], y.iloc[train,:])
    score = model.score(X.iloc[test,:], y.iloc[test,:])
    scores.append(score)

print(scores)
# Out:
# [0.655411742177868, 0.6640707979776372]

# %%
X = pd.DataFrame(Data_L[['Compression Pressure (MPa)','Particle size (%)150 - 250 µm','Screen shape  round']])
y = pd.DataFrame(Data_L['Ha (mm)'])

model = LinearRegression()
scores = []
kfold = KFold(n_splits=2, shuffle=True, random_state=42)

for i, (train, test) in enumerate(kfold.split(X, y)):
    model.fit(X.iloc[train,:], y.iloc[train,:])
    score = model.score(X.iloc[test,:], y.iloc[test,:])
    scores.append(score)

print(scores)
# Out:
# [0.8039033854974913, 0.8202865991665163]

# %%
X = pd.DataFrame(Data_L[['TCP (%)','Compression Pressure (MPa)','Particle size (%)150 - 250 µm','Screen shape  round']])
y = pd.DataFrame(Data_L['Ha (mm)'])

model = LinearRegression()
scores = []
kfold = KFold(n_splits=2, shuffle=True, random_state=42)

for i, (train, test) in enumerate(kfold.split(X, y)):
    model.fit(X.iloc[train,:], y.iloc[train,:])
    score = model.score(X.iloc[test,:], y.iloc[test,:])
    scores.append(score)

print('Individual scores:',scores)
print('Average score:', sum(scores)/len(scores))
# Out:
# Individual scores: [0.8359598024722926, 0.8490656114660412]
# Average score: 0.8425127069691669

# %%
X = pd.DataFrame(Data_L[['TCP (%)','Compression Pressure (MPa)','Particle size (%)150 - 250 µm','Screen shape  round']])
y = pd.DataFrame(Data_L['Ha (mm)'])

model = LinearRegression()
scores = []
kfold = KFold(n_splits=2, shuffle=True, random_state=42)

for i, (train, test) in enumerate(kfold.split(X, y)):
    model.fit(X.iloc[train,:], y.iloc[train,:])
    score = model.score(X.iloc[test,:], y.iloc[test,:])
    scores.append(score)
    
print('Individual scores:',scores)
print('Average score:', sum(scores)/len(scores))
# Out:
# Individual scores: [0.8359598024722926, 0.8490656114660412]
# Average score: 0.8425127069691669

# %% [markdown]
# ### Ridge, Lasso and ElasticNet Regularization

# %%
from sklearn.cross_validation import train_test_split, ShuffleSplit
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
X = pd.DataFrame(Data_L[['TCP (%)','Compression Pressure (MPa)','Particle size (%)150 - 250 µm','Screen shape  round']])
y = pd.DataFrame(Data_L['Ha (mm)'])

X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.3, random_state=4)
model_rr = Ridge(alpha=0.01)
model_rr.fit(X_train, y_train)

Ridge_train_score = model_rr.score(X_train,y_train)
Ridge_test_score = model_rr.score(X_test, y_test)
Predict_test_ridge = model_rr.predict(X_test)

print("Ridge regression train score:", Ridge_train_score)
print("Ridge regression test score:", Ridge_test_score)
print('RSquare value(test):',np.round(model_rr.score(X_test, y_test)*100,2))
print('MSE for test data:',np.round(metrics.mean_squared_error(y_test, Predict_test_ridge),2))
# Out:
# Ridge regression train score: 0.8792323146653765
# Ridge regression test score: 0.7257113926324887
# RSquare value(test): 72.57
# MSE for test data: 0.01

# %%
X = pd.DataFrame(Data_L[['TCP (%)','Compression Pressure (MPa)','Particle size (%)150 - 250 µm','Screen shape  round']])
y = pd.DataFrame(Data_L['Ha (mm)'])

X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.3, random_state=4)
model_lr = Lasso()
model_lr.fit(X_train, y_train)
coeff_used = np.sum(model_lr.coef_!=0)

Lasso_train_score = model_lr.score(X_train,y_train)
Lasso_test_score = model_lr.score(X_test, y_test)
Predict_test_Lasso = model_lr.predict(X_test)

print("Lasso regression train score:", Lasso_train_score)
print("Lasso regression test score:", Lasso_test_score)
print("number of features used: ", coeff_used)
print('RSquare value(test):',np.round(model_lr.score(X_test, y_test)*100,2))
print('MSE for test data:',np.round(metrics.mean_squared_error(y_test, Predict_test_Lasso),2))
# Out:
# Lasso regression train score: 0.6772132518669731
# Lasso regression test score: 0.47140735496127895
# number of features used:  1
# RSquare value(test): 47.14
# MSE for test data: 0.02

# %%
X = pd.DataFrame(Data_L[['TCP (%)','Compression Pressure (MPa)','Particle size (%)150 - 250 µm','Screen shape  round']])
y = pd.DataFrame(Data_L['Ha (mm)'])

X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.3, random_state=4)
model_enr = ElasticNet()
model_enr.fit(X_train, y_train)

ElasticNet_train_score = model_enr.score(X_train,y_train)
ElasticNet_test_score = model_enr.score(X_test, y_test)
Predict_test_ElasticNet = model_enr.predict(X_test)

print("ElasticNet regression train score:", ElasticNet_train_score)
print("ElasticNet regression test score:", ElasticNet_test_score)
print('RSquare value(test):',np.round(model_enr.score(X_test, y_test)*100,2))
print('MSE for test data:',np.round(metrics.mean_squared_error(y_test, Predict_test_ElasticNet),2))
# Out:
# ElasticNet regression train score: 0.6886809090594546
# ElasticNet regression test score: 0.4684617607778283
# RSquare value(test): 46.85
# MSE for test data: 0.02

# %% [markdown]
# Conclusion: Ridge Regression has Provided better result

# %% [markdown]
# # Pilot scale sample runs

# %% [markdown]
# ### Linear Regression with K-Fold Cross Validation for Ha as Response Variable

# %%
Data_P = Data.loc['1P':'48 P']

# %%
X = pd.DataFrame(Data_P[['TCP (%)','SSG (%)','Compression Pressure (MPa)','Particle size (%)150 - 250 µm','Screen shape  round']])
y = pd.DataFrame(Data_P['Ha (mm)'])

model = LinearRegression()
scores = []
kfold = KFold(n_splits=2, shuffle=True, random_state=42)

for i, (train, test) in enumerate(kfold.split(X, y)):
    model.fit(X.iloc[train,:], y.iloc[train,:])
    score = model.score(X.iloc[test,:], y.iloc[test,:])
    scores.append(score)
    
print('Individual scores:',scores)
print('Average score:', sum(scores)/len(scores))
# Out:
# Individual scores: [0.8955903168540705, 0.8168242709785698]
# Average score: 0.8562072939163201

# %%
X = pd.DataFrame(Data_P[['TCP (%)','Compression Pressure (MPa)','Particle size (%)150 - 250 µm','Screen shape  round']])
y = pd.DataFrame(Data_P['Ha (mm)'])

X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.3, random_state=4)
model_rr = Ridge(alpha=0.01)
model_rr.fit(X_train, y_train)

Ridge_train_score = model_rr.score(X_train,y_train)
Ridge_test_score = model_rr.score(X_test, y_test)
Predict_test_ridge = model_rr.predict(X_test)

print("Ridge regression train score:", Ridge_train_score)
print("Ridge regression test score:", Ridge_test_score)
print('RSquare value(test):',np.round(model_rr.score(X_test, y_test)*100,2))
print('MSE for test data:',np.round(metrics.mean_squared_error(y_test, Predict_test_ridge),2))
# Out:
# Ridge regression train score: 0.9353719261024712
# Ridge regression test score: 0.8880983845091518
# RSquare value(test): 88.81
# MSE for test data: 0.01

# %%
X = pd.DataFrame(Data_P[['TCP (%)','Compression Pressure (MPa)','Particle size (%)150 - 250 µm','Screen shape  round']])
y = pd.DataFrame(Data_P['Ha (mm)'])

X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.3, random_state=4)
model_lr = Lasso()
model_lr.fit(X_train, y_train)
coeff_used = np.sum(model_lr.coef_!=0)

Lasso_train_score = model_lr.score(X_train,y_train)
Lasso_test_score = model_lr.score(X_test, y_test)
Predict_test_Lasso = model_lr.predict(X_test)

print("Lasso regression train score:", Lasso_train_score)
print("Lasso regression test score:", Lasso_test_score)
print("number of features used: ", coeff_used)
print('RSquare value(test):',np.round(model_lr.score(X_test, y_test)*100,2))
print('MSE for test data:',np.round(metrics.mean_squared_error(y_test, Predict_test_Lasso),2))
# Out:
# Lasso regression train score: 0.9132057926882586
# Lasso regression test score: 0.8571006287678915
# number of features used:  1
# RSquare value(test): 85.71
# MSE for test data: 0.01

# %%
X = pd.DataFrame(Data_P[['TCP (%)','Compression Pressure (MPa)','Particle size (%)150 - 250 µm','Screen shape  round']])
y = pd.DataFrame(Data_P['Ha (mm)'])

X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.3, random_state=4)
model_enr = ElasticNet()
model_enr.fit(X_train, y_train)

ElasticNet_train_score = model_enr.score(X_train,y_train)
ElasticNet_test_score = model_enr.score(X_test, y_test)
Predict_test_ElasticNet = model_enr.predict(X_test)

print("ElasticNet regression train score:", ElasticNet_train_score)
print("ElasticNet regression test score:", ElasticNet_test_score)
print('RSquare value(test):',np.round(model_enr.score(X_test, y_test)*100,2))
print('MSE for test data:',np.round(metrics.mean_squared_error(y_test, Predict_test_ElasticNet),2))
# Out:
# ElasticNet regression train score: 0.9297418134568743
# ElasticNet regression test score: 0.8771350310557018
# RSquare value(test): 87.71
# MSE for test data: 0.01

# %% [markdown]
# # Commercial scale sample runs

# %%
Data_C = Data.loc['1 C':'36 C']

# %%
X = pd.DataFrame(Data_C[['TCP (%)','Compression Pressure (MPa)','Particle size (%)150 - 250 µm','Screen shape  round']])
y = pd.DataFrame(Data_C['Ha (mm)'])

model = LinearRegression()
scores = []
kfold = KFold(n_splits=2, shuffle=True, random_state=42)

for i, (train, test) in enumerate(kfold.split(X, y)):
    model.fit(X.iloc[train,:], y.iloc[train,:])
    score = model.score(X.iloc[test,:], y.iloc[test,:])
    scores.append(score)
    
print('Individual scores:',scores)
print('Average score:', sum(scores)/len(scores))
# Out:
# Individual scores: [0.8338146146653096, 0.8679157140287725]
# Average score: 0.8508651643470411

# %% [markdown]
# ### Ridge, Lasso and ElasticNet Regularization

# %%
X = pd.DataFrame(Data_C[['TCP (%)','Compression Pressure (MPa)','Particle size (%)150 - 250 µm','Screen shape  round']])
y = pd.DataFrame(Data_C['Ha (mm)'])

X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.3, random_state=4)
model_rr = Ridge(alpha=0.01)
model_rr.fit(X_train, y_train)

Ridge_train_score = model_rr.score(X_train,y_train)
Ridge_test_score = model_rr.score(X_test, y_test)
Predict_test_ridge = model_rr.predict(X_test)

print("Ridge regression train score:", Ridge_train_score)
print("Ridge regression test score:", Ridge_test_score)
print('RSquare value(test):',np.round(model_rr.score(X_test, y_test)*100,2))
print('MSE for test data:',np.round(metrics.mean_squared_error(y_test, Predict_test_ridge),2))
# Out:
# Ridge regression train score: 0.9155898305584477
# Ridge regression test score: 0.532992669937665
# RSquare value(test): 53.3
# MSE for test data: 0.01

# %%
X = pd.DataFrame(Data_C[['TCP (%)','Compression Pressure (MPa)','Particle size (%)150 - 250 µm','Screen shape  round']])
y = pd.DataFrame(Data_C['Ha (mm)'])

X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.3, random_state=4)
model_lr = Lasso()
model_lr.fit(X_train, y_train)
coeff_used = np.sum(model_lr.coef_!=0)

Lasso_train_score = model_lr.score(X_train,y_train)
Lasso_test_score = model_lr.score(X_test, y_test)
Predict_test_Lasso = model_lr.predict(X_test)

print("Lasso regression train score:", Lasso_train_score)
print("Lasso regression test score:", Lasso_test_score)
print("number of features used: ", coeff_used)
print('RSquare value(test):',np.round(model_lr.score(X_test, y_test)*100,2))
print('MSE for test data:',np.round(metrics.mean_squared_error(y_test, Predict_test_Lasso),2))
# Out:
# Lasso regression train score: 0.8969796229685046
# Lasso regression test score: 0.7013581113889349
# number of features used:  1
# RSquare value(test): 70.14
# MSE for test data: 0.01

# %%
X = pd.DataFrame(Data_C[['TCP (%)','Compression Pressure (MPa)','Particle size (%)150 - 250 µm','Screen shape  round']])
y = pd.DataFrame(Data_C['Ha (mm)'])

X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.3, random_state=4)
model_enr = ElasticNet()
model_enr.fit(X_train, y_train)

ElasticNet_train_score = model_enr.score(X_train,y_train)
ElasticNet_test_score = model_enr.score(X_test, y_test)
Predict_test_ElasticNet = model_enr.predict(X_test)

print("ElasticNet regression train score:", ElasticNet_train_score)
print("ElasticNet regression test score:", ElasticNet_test_score)
print('RSquare value(test):',np.round(model_enr.score(X_test, y_test)*100,2))
print('MSE for test data:',np.round(metrics.mean_squared_error(y_test, Predict_test_ElasticNet),2))
# Out:
# ElasticNet regression train score: 0.9094771380312697
# ElasticNet regression test score: 0.6451301274943713
# RSquare value(test): 64.51
# MSE for test data: 0.01
